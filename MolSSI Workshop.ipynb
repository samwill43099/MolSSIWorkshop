# %% [markdown]
# # MolSSI Workshop
# ## Introduction
# This lesson covers Python basics like variable creation and assignment and using the Jupyter notebook.

# %%
3+7
# Out:
# 10

# %%
deltaH = -541.5 #kj/mole
deltaS = 10.4 #kj/(mole k)
temp = 298 #Kelvin
deltaG = deltaH - temp * deltaS

# %%
print(deltaG)
# Out:
# -3640.7000000000003

# %%
print(deltaG)
deltaG_joules = deltaG * 1000
print(deltaG)
print(deltaG_joules)
# Out:
# -3640.7000000000003
# -3640.7000000000003
# -3640700.0000000005

# %%
# I can instead assign all my variables at once.
deltaH, deltaS, temp = -541.5, 10.4, 298
deltaG = deltaH - temp *deltaS
print(deltaG)
# Out:
# -3640.7000000000003

# %%
# This is a list
energy_kcal=[-13.4, -2.7, 5.4, 42.1]
# I can determine its length
energy_length=len(energy_kcal)
print('The length of this list is', energy_length)
# Out:
# The length of this list is 4

# %%
#Print the first element of the list
print(energy_kcal[0])
# Out:
# -13.4

# %%
# Convert the second list element to kJ
energy_kilojoules=energy_kcal[1]*4.184
print(energy_kilojoules)
# Out:
# -11.296800000000001

# %%
short_list= energy_kcal[0:2]

# %%
print(short_list)
# Out:
# [-13.4, -2.7]

# %%
print(energy_kcal)
energy_kcal[0:2]
print(energy_kcal)
# Out:
# [-13.4, -2.7, 5.4, 42.1]
# [-13.4, -2.7, 5.4, 42.1]

# %%
for number in energy_kcal:
    kJ=number*4.184
    print(kJ)
# Out:
# -56.0656
# -11.296800000000001
# 22.593600000000002
# 176.1464

# %%
energy_kJ=[]
for number in energy_kcal:
    kJ=number*4.184
    energy_kJ.append(kJ)

print(energy_kJ)
# Out:
# [-56.0656, -11.296800000000001, 22.593600000000002, 176.1464]

# %%
energy_kJ=[]
for number in energy_kcal:
    kJ=number*4.184
    energy_kJ.append(kJ)

print(energy_kJ)
# Out:
# [-56.0656, -11.296800000000001, 22.593600000000002, 176.1464]

# %%
negative_energy_kJ=[]

for number in energy_kJ:
    if number<0:
        negative_energy_kJ.append(number)
print(negative_energy_kJ)
# Out:
# [-56.0656, -11.296800000000001]

# %%
negative_numbers = []
for number in energy_kJ:
    if number < 0 or number == 0:
        negative_numbers.append(number)
        
print(negative_numbers)
# Out:
# [-56.0656, -11.296800000000001]

# %%
number_list=[]
data_list = ['-12.5',14.4,8.1,"42"]
for item in data_list:
    if type(item) is str:
        number_list.append(float(item))
    else:
        number_list.append(item)
print(number_list)
# Out:
# [-12.5, 14.4, 8.1, 42.0]

# %% [markdown]
# ## File Parsing
# This lesson teaches how to sort through info in a text file and extract particular info.

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C02F-5876
#
#  Directory of C:\Users\samwi\OneDrive\Desktop\cms-workshop
#
# 11/28/2020  04:38 PM    <DIR>          .
# 11/28/2020  04:38 PM    <DIR>          ..
# 11/25/2020  10:34 AM    <DIR>          .ipynb_checkpoints
# 11/28/2020  04:27 PM            75,414 all_samples.png
# 11/28/2020  04:27 PM                60 bond_lengths.txt
# 11/21/2020  01:12 PM    <DIR>          data
# 11/21/2020  01:11 PM           237,019 data.zip
# 11/28/2020  04:27 PM               299 energies.txt
# 11/28/2020  04:27 PM             3,924 Etot.txt
# 11/28/2020  04:38 PM         1,056,376 MolSSI Workshop.ipynb
# 11/28/2020  04:27 PM            16,600 THR4_ASP.png
# 11/28/2020  04:27 PM            18,680 THR4_ATP.png
# 11/28/2020  04:27 PM            23,937 two_samples.png
# 11/28/2020  04:27 PM            16,806 TYR6_ASP.png
# 11/28/2020  04:27 PM            18,900 TYR6_ATP.png
#               11 File(s)      1,468,015 bytes
# ...

# %%
ls data
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C02F-5876
#
#  Directory of C:\Users\samwi\OneDrive\Desktop\cms-workshop\data
#
# 11/21/2020  01:12 PM    <DIR>          .
# 11/21/2020  01:12 PM    <DIR>          ..
# 11/21/2020  01:12 PM           212,934 03_Prod.mdout
# 11/21/2020  01:12 PM               619 benzene.xyz
# 11/21/2020  01:12 PM             2,471 buckminsterfullerene.xyz
# 11/21/2020  01:12 PM           355,359 distance_data_headers.csv
# 11/21/2020  01:12 PM    <DIR>          outfiles
# 11/21/2020  01:12 PM            61,568 sapt.out
# 11/21/2020  01:12 PM               155 water.xyz
#                6 File(s)        633,106 bytes
#                3 Dir(s)  90,995,916,800 bytes free

# %%
pwd
# Out:
# 'C:\\Users\\samwi\\OneDrive\\Desktop\\cms-workshop'

# %%
"""When we write a script, we want it to be usable on any
operating system, thus we will use a python module called os.path""" 

import os
ethanol_file= os.path.join('data','outfiles','ethanol.out')
print(ethanol_file)
# Out:
# data\outfiles\ethanol.out

# %%
# To get the absolute file path from the relative path os.path.abspath(path)
print(os.path.abspath(ethanol_file))
# Out:
# C:\Users\samwi\OneDrive\Desktop\cms-workshop\data\outfiles\ethanol.out

# %%
"""Before we can read a file we must open it using its path. Here we are
opening a file, to read (r) and assigning it a file handle. (we could
open a file to write (w) or append (a))"""

outfile = open(ethanol_file,"r")

"""Once it is open there are multiple ways to read info from a text file,
the best method depends on the type of data and the type of analysis we 
are doing, the most generic way to read info is the readlines function
this function gets our file as a list of strings each of which is one line 
of the file"""

data = outfile.readlines()

# %%
"""After you open and read info from a file object you should close it"""
outfile.close()

# %%
"""Another way to open a file that auto closes it"""
with open(ethanol_file,"r") as outfile:
    data = outfile.readlines()

# %%
len(data)
# Out:
# 270

# %%
for line in data:
    print(line)
# Out:
#     -----------------------------------------------------------------------
#
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#
#                                Psi4 1.1 release
#
#
#
#                          Git: Rev {HEAD} add49b9
#
#
#
#
#
#     R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,
#
#     A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,
#
#     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,
#
#     H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,
#
#     P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,
#
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,
#
#     J. Chem. Theory Comput. in press (2017).
#
#     (doi: 10.1021/acs.jctc.7b00174)
#
#
#
#     -----------------------------------------------------------------------
#
#
#
#
#
#     Psi4 started on: Tuesday, 27 June 2017 12:10PM
#
#
#
#     Process ID:  10591
#
# ...

# %%
for line in data:
    if 'Final Energy' in line:
        energy_line = line
        print(energy_line)
# Out:
#   @DF-RHF Final Energy:  -154.09130176573018

# %%
energy_line.split()
# Out:
# ['@DF-RHF', 'Final', 'Energy:', '-154.09130176573018']

# %% [raw]
# print(energy_line.split(':'))

# %%
energy_line.split(':')
# Out:
# ['  @DF-RHF Final Energy', '  -154.09130176573018\n']

# %%
words = energy_line.split()
print(words)
# Out:
# ['@DF-RHF', 'Final', 'Energy:', '-154.09130176573018']

# %%
energy=words[3]
print(energy)
# Out:
# -154.09130176573018

# %%
"""We can also assign by indexing in reveres. See the -1 index of words
is the same as the 3rd element which we defined as energy"""
energy==words[-1]
# Out:
# True

# %%
"""To use the variable energy in a math operation we must cast it to the
data type float"""
energy = float(energy)

# %%
""" If we thought ahead we could have changed the data type when we
assigned the variable"""
energy = float(words[3])

# %%
type(energy)
# Out:
# float

# %%
sapt_file = os.path.join('data','sapt.out')

# %%
with open(sapt_file,"r") as outfile:
    data_2=outfile.readlines()

# %%
for line in data_2:
    if "Electrostatics" in line and "sSAPT0" not in line:
        electrostatics_energy=line.split()[3]
        print(line.split()[0]," : ", line.split()[3]," kcal/mol")
    if "Exchange" in line and "sSAPT0" not in line:
        exchange_energy=line.split()[3]
        print(line.split()[0]," : ", line.split()[3]," kcal/mol")
    if "Induction" in line and "sSAPT0" not in line:
        induction_energy = line.split()[3]
        print(line.split()[0]," : ", line.split()[3]," kcal/mol")
    if "Dispersion" in line and "sSAPT0" not in line:
        dispersion_energy = line.split()[3]
        print(line.split()[0]," : ", line.split()[3]," kcal/mol")
total_energy=float(electrostatics_energy)+float(exchange_energy)+float(induction_energy)+float(dispersion_energy)
print("Total Energy : ",total_energy, "kcal/mol")
# Out:
# Electrostatics  :  -2.25850118  kcal/mol
# Exchange  :  2.27730198  kcal/mol
# Induction  :  -0.52169330  kcal/mol
# Dispersion  :  -0.94466770  kcal/mol
# Total Energy :  -1.4475602000000003 kcal/mol

# %%
for linenum, line in enumerate(data):
    if 'Center' in line:
        print(linenum)
        print(line)
# Out:
# 77
#        Center              X                  Y                   Z               Mass

# %% [markdown]
# ## Processing Multiple Files and Writing Files
# How an we use a for loop to parse the output files of multiple files.
# We will use the glob library which allows us to read in multiple files.
# A library ontains modules and functions whihs do a specific computational task.

# %%
# We must use the OS library to handle file paths
import os

# %%
ls data\outfiles
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C02F-5876
#
#  Directory of C:\Users\samwi\OneDrive\Desktop\cms-workshop\data\outfiles
#
# 11/21/2020  01:12 PM    <DIR>          .
# 11/21/2020  01:12 PM    <DIR>          ..
# 11/21/2020  01:12 PM            12,750 butanol.out
# 11/21/2020  01:12 PM            18,728 decanol.out
# 11/21/2020  01:12 PM            10,639 ethanol.out
# 11/21/2020  01:12 PM            15,770 heptanol.out
# 11/21/2020  01:12 PM            14,767 hexanol.out
# 11/21/2020  01:12 PM             9,719 methanol.out
# 11/21/2020  01:12 PM            17,727 nonanol.out
# 11/21/2020  01:12 PM            16,788 octanol.out
# 11/21/2020  01:12 PM            13,762 pentanol.out
# 11/21/2020  01:12 PM            11,710 propanol.out
#               10 File(s)        142,360 bytes
#                2 Dir(s)  90,995,904,512 bytes free

# %%
# We use the os.path module to point to the directory where the outfiles are.
outfile_directory=os.path.join('data','outfiles')

# %%
# In order to get all of the files which match a specific pattern, we use a wildcard character *
file_location=os.path.join('data','outfiles','*.out')
print(file_location)
# This will specify the relative path of all files in the outfile directory that end in .out
# Out:
# data\outfiles\*.out

# %%
# No we we use the function glob in the library glob to get a list of all the file names that match the file_location

import glob
filenames= glob.glob(file_location)
print(filenames)
# Out:
# ['data\\outfiles\\butanol.out', 'data\\outfiles\\decanol.out', 'data\\outfiles\\ethanol.out', 'data\\outfiles\\heptanol.out', 'data\\outfiles\\hexanol.out', 'data\\outfiles\\methanol.out', 'data\\outfiles\\nonanol.out', 'data\\outfiles\\octanol.out', 'data\\outfiles\\pentanol.out', 'data\\outfiles\\propanol.out']

# %%
# Now we an use a for loop to parse every file we just read in

for f in filenames:
    with open(f,'r') as outfile:
        data= outfile.readlines()
    for line in data:
        if 'Final Energy' in line:
            energy_line = line
            words = energy_line.split()
            energy = float(words[3])
            print(energy)
# Out:
# -232.1655798347283
# -466.3836241400086
# -154.09130176573018
# -349.27397687072676
# -310.2385332251633
# -115.04800861868374
# -427.3465180082815
# -388.3110864554743
# -271.20138119895074
# -193.12836249728798

# %%
# These numbers are meaningless without knowledge of the molecule they came from
# we can print the name of the file using the basename function in the os.path module

first_file = filenames[0]
print(first_file)
file_name=os.path.basename(first_file)
print(file_name)
# Out:
# data\outfiles\butanol.out
# butanol.out

# %%
#How would you extract the molecule name from the example above?
molecule=file_name.split('.')[0]
print(molecule)
# Out:
# butanol

# %%
# we can now modify our loop so it prints the file name with each energy
for f in filenames:
    # get the molecule name
    file_name=os.path.basename(f)
    split_filename=file_name.split('.')
    molecule_name=split_filename[0]
    
    # Read the data
    with open(f,'r') as outfile:
        data=outfile.readlines()
    
    # Loop through the data
    for line in data:
        if 'Final Energy' in line:
            energy_line=line
            words=energy_line.split()
            energy= float(words[3])
            print(molecule_name, energy)
# Out:
# butanol -232.1655798347283
# decanol -466.3836241400086
# ethanol -154.09130176573018
# heptanol -349.27397687072676
# hexanol -310.2385332251633
# methanol -115.04800861868374
# nonanol -427.3465180082815
# octanol -388.3110864554743
# pentanol -271.20138119895074
# propanol -193.12836249728798

# %%
# We might want to print this to a file
# in general to open a file for writing you use the syntax
# filehandle= open('file_name.txt','w+')
# Python can only write strings to files, to convert what we have now to a string we place a capital F in front of the line we want to print

datafile=open('energies.txt','w+') #This opens the file for writing

for f in filenames:
    # get the molecule name
    file_name=os.path.basename(f)
    split_filename=file_name.split('.')
    molecule_name=split_filename[0]
    
    # Read the data
    with open(f,'r') as outfile:
        data=outfile.readlines()
    
    # Loop through the data
    for line in data:
        if 'Final Energy' in line:
            energy_line=line
            words=energy_line.split()
            energy= float(words[3])
            datafile.write(F'{molecule_name}\t {energy}\n') #this command prints the info to the file and the \t seperates the file name from the energy using a tab and the \n is the new line character
            
datafile.close() #Your computer does not write anything until you close the file

# After running this code, a new file "energies.txt" is in the directory where the code is ran

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C02F-5876
#
#  Directory of C:\Users\samwi\OneDrive\Desktop\cms-workshop
#
# 11/28/2020  04:38 PM    <DIR>          .
# 11/28/2020  04:38 PM    <DIR>          ..
# 11/25/2020  10:34 AM    <DIR>          .ipynb_checkpoints
# 11/28/2020  04:27 PM            75,414 all_samples.png
# 11/28/2020  04:27 PM                60 bond_lengths.txt
# 11/21/2020  01:12 PM    <DIR>          data
# 11/21/2020  01:11 PM           237,019 data.zip
# 11/29/2020  10:41 AM               299 energies.txt
# 11/28/2020  04:27 PM             3,924 Etot.txt
# 11/28/2020  04:38 PM         1,056,376 MolSSI Workshop.ipynb
# 11/28/2020  04:27 PM            16,600 THR4_ASP.png
# 11/28/2020  04:27 PM            18,680 THR4_ATP.png
# 11/28/2020  04:27 PM            23,937 two_samples.png
# 11/28/2020  04:27 PM            16,806 TYR6_ASP.png
# 11/28/2020  04:27 PM            18,900 TYR6_ATP.png
#               11 File(s)      1,468,015 bytes
# ...

# %%
with open('energies.txt','r') as fileofinterest:
    imlookingforthisfile=fileofinterest.readlines()
print(imlookingforthisfile)
# Out:
# ['butanol\t -232.1655798347283\n', 'decanol\t -466.3836241400086\n', 'ethanol\t -154.09130176573018\n', 'heptanol\t -349.27397687072676\n', 'hexanol\t -310.2385332251633\n', 'methanol\t -115.04800861868374\n', 'nonanol\t -427.3465180082815\n', 'octanol\t -388.3110864554743\n', 'pentanol\t -271.20138119895074\n', 'propanol\t -193.12836249728798\n']

# %%
for line in imlookingforthisfile:
    print(line)
# Out:
# butanol	 -232.1655798347283
#
# decanol	 -466.3836241400086
#
# ethanol	 -154.09130176573018
#
# heptanol	 -349.27397687072676
#
# hexanol	 -310.2385332251633
#
# methanol	 -115.04800861868374
#
# nonanol	 -427.3465180082815
#
# octanol	 -388.3110864554743
#
# pentanol	 -271.20138119895074
#
# propanol	 -193.12836249728798

# %% [markdown]
# ### Project Assignment
# In the lesson materials, there is a file called 03_Prod.mdout. This is a file output by the Amber molecular dynamics simulation program. Your assignment is to parse this file, and write a new file containing a list of the > total energies. Name your file Etot.txt.

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C02F-5876
#
#  Directory of C:\Users\samwi\OneDrive\Desktop\cms-workshop
#
# 11/28/2020  04:38 PM    <DIR>          .
# 11/28/2020  04:38 PM    <DIR>          ..
# 11/25/2020  10:34 AM    <DIR>          .ipynb_checkpoints
# 11/28/2020  04:27 PM            75,414 all_samples.png
# 11/28/2020  04:27 PM                60 bond_lengths.txt
# 11/21/2020  01:12 PM    <DIR>          data
# 11/21/2020  01:11 PM           237,019 data.zip
# 11/29/2020  10:41 AM               299 energies.txt
# 11/28/2020  04:27 PM             3,924 Etot.txt
# 11/28/2020  04:38 PM         1,056,376 MolSSI Workshop.ipynb
# 11/28/2020  04:27 PM            16,600 THR4_ASP.png
# 11/28/2020  04:27 PM            18,680 THR4_ATP.png
# 11/28/2020  04:27 PM            23,937 two_samples.png
# 11/28/2020  04:27 PM            16,806 TYR6_ASP.png
# 11/28/2020  04:27 PM            18,900 TYR6_ATP.png
#               11 File(s)      1,468,015 bytes
# ...

# %%
ls data
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C02F-5876
#
#  Directory of C:\Users\samwi\OneDrive\Desktop\cms-workshop\data
#
# 11/21/2020  01:12 PM    <DIR>          .
# 11/21/2020  01:12 PM    <DIR>          ..
# 11/21/2020  01:12 PM           212,934 03_Prod.mdout
# 11/21/2020  01:12 PM               619 benzene.xyz
# 11/21/2020  01:12 PM             2,471 buckminsterfullerene.xyz
# 11/21/2020  01:12 PM           355,359 distance_data_headers.csv
# 11/21/2020  01:12 PM    <DIR>          outfiles
# 11/21/2020  01:12 PM            61,568 sapt.out
# 11/21/2020  01:12 PM               155 water.xyz
#                6 File(s)        633,106 bytes
#                3 Dir(s)  90,995,904,512 bytes free

# %%
import os
Amber_filename = os.path.join('data','03_Prod.mdout')
with open(Amber_filename) as file:
    amberfile = file.readlines()

# %%
for line in amberfile:
    print(line)
# Out:
#           -------------------------------------------------------
#
#           Amber 14 SANDER                              2014
#
#           -------------------------------------------------------
#
#
#
# | Run on 06/30/2015 at 15:14:49
#
#   [-O]verwriting output
#
#
#
# File Assignments:
#
# |  MDIN: 03_Prod.in
#
# | MDOUT: 03_Prod.mdout
#
# |INPCRD: 02_Heat.rst
#
# |  PARM: prmtop
#
# |RESTRT: 03_Prod.rst
#
# |  REFC: refc
#
# | MDVEL: mdvel
#
# | MDFRC: mdfrc
#
# |  MDEN: mden
#
# | MDCRD: 03_Prod.mdcrd
#
# |MDINFO: 03_Prod.info
#
# |  MTMD: mtmd
#
# |INPDIP: inpdip
#
# |RSTDIP: rstdip
#
# |INPTRA: inptraj
#
#
#
#
#
#  Here is the input file:
#
#
#
# Production
#
#  &cntrl
#
#   imin=0,
#
#   ntx=5,
#
#   irest=1,
#
#   nstlim=30000,
#
#   dt=0.002,
#
#   ntf=2,
#
#   ntc=2,
#
#   temp0=300.0,
#
#   ntpr=100,
#
#   ntwx=100,
#
#   cut=8.0,
#
#   ntb=2,
#
#   ntp=1,
#
#   ntt=3,
#
#   gamma_ln=2.0,
#
#   ig=-1,
#
#  /
#
#
#
# ...

# %%
Amberdatafile=open('Etot.txt','w+')

for line in amberfile:
    if 'Etot' in line:
        energy_line=line
        words = energy_line.split()
        energy=words[2]
        Amberdatafile.write(F'{energy} \n')
Amberdatafile.close()

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C02F-5876
#
#  Directory of C:\Users\samwi\OneDrive\Desktop\cms-workshop
#
# 11/28/2020  04:38 PM    <DIR>          .
# 11/28/2020  04:38 PM    <DIR>          ..
# 11/25/2020  10:34 AM    <DIR>          .ipynb_checkpoints
# 11/28/2020  04:27 PM            75,414 all_samples.png
# 11/28/2020  04:27 PM                60 bond_lengths.txt
# 11/21/2020  01:12 PM    <DIR>          data
# 11/21/2020  01:11 PM           237,019 data.zip
# 11/29/2020  10:41 AM               299 energies.txt
# 11/29/2020  10:41 AM             3,924 Etot.txt
# 11/28/2020  04:38 PM         1,056,376 MolSSI Workshop.ipynb
# 11/28/2020  04:27 PM            16,600 THR4_ASP.png
# 11/28/2020  04:27 PM            18,680 THR4_ATP.png
# 11/28/2020  04:27 PM            23,937 two_samples.png
# 11/28/2020  04:27 PM            16,806 TYR6_ASP.png
# 11/28/2020  04:27 PM            18,900 TYR6_ATP.png
#               11 File(s)      1,468,015 bytes
# ...

# %%
with open('Etot.txt','r') as outfile:
    projectcheck=outfile.readlines()

# %%
for line in projectcheck:
    print(line)
# Out:
# -4585.1049
#
# -4573.5326
#
# -4548.1223
#
# -4525.3410
#
# -4542.8995
#
# -4550.9376
#
# -4543.8652
#
# -4570.4109
#
# -4550.4225
#
# -4585.2078
#
# -4577.3788
#
# -4583.5594
#
# -4605.5086
#
# -4615.4200
#
# -4583.6069
#
# -4534.2492
#
# -4571.4911
#
# -4580.2937
#
# -4555.4327
#
# -4567.5687
#
# -4566.0038
#
# -4547.9737
#
# -4603.6717
#
# -4611.0889
#
# -4694.2189
#
# -4678.6558
#
# -4679.2889
#
# -4650.4214
#
# -4637.4849
#
# -4677.2461
#
# -4659.6974
#
# -4592.8300
#
# -4622.1237
#
# -4626.0868
#
# -4614.5996
#
# -4625.5348
#
# -4569.7752
#
# -4625.0792
#
# -4653.4614
#
# -4637.6852
#
# -4643.8673
#
# -4619.5255
#
# -4663.3843
#
# -4631.8386
#
# -4680.3524
#
# -4722.1579
#
# -4696.5022
#
# -4729.6126
#
# -4703.1835
#
# -4707.8668
#
# -4660.0768
#
# -4673.0967
#
# -4656.3795
#
# -4627.9210
#
# -4599.7806
#
# -4648.8831
#
# -4649.4773
#
# -4665.3345
#
# -4693.9727
#
# -4726.4832
#
# -4744.9909
#
# -4788.9469
#
# -4724.8673
#
# -4724.9143
#
# -4685.3320
#
# -4721.0018
#
# ...

# %% [markdown]
# ## Working with Tabular Data
# ### Reading in Tabular Data

# %%
import numpy #Here we import a library that has functions to perform calculations on tabular data
help(numpy.genfromtxt)
# Out:
# Help on function genfromtxt in module numpy:
#
# genfromtxt(fname, dtype=<class 'float'>, comments='#', delimiter=None, skip_header=0, skip_footer=0, converters=None, missing_values=None, filling_values=None, usecols=None, names=None, excludelist=None, deletechars=" !#$%&'()*+,-./:;<=>?@[\\]^{|}~", replace_space='_', autostrip=False, case_sensitive=True, defaultfmt='f%i', unpack=None, usemask=False, loose=True, invalid_raise=True, max_rows=None, encoding='bytes')
#     Load data from a text file, with missing values handled as specified.
#
#     Each line past the first `skip_header` lines is split at the `delimiter`
#     character, and characters following the `comments` character are discarded.
#
#     Parameters
#     ----------
#     fname : file, str, pathlib.Path, list of str, generator
#         File, filename, list, or generator to read.  If the filename
#         extension is `.gz` or `.bz2`, the file is first decompressed. Note
# ...

# %%
import os

distance_file = os.path.join('data','distance_data_headers.csv')

distances = numpy.genfromtxt(fname=distance_file, delimiter=',', dtype='unicode')

print(distances)
# Out:
# [['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']
#  ['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %% [markdown]
# ### Manipulating Tabular Data

# %%
headers = distances [0]
print(headers)
# Out:
# ['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']

# %%
data=distances[1:]
print(data)
# Out:
# [['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ['3' '9.0066' '6.0637' '13.0924' '11.3043']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %%
data=data.astype(numpy.float) #Here we cast the data table to type float
print(data)
# Out:
# [[1.00000e+00 8.95420e+00 5.80240e+00 1.15478e+01 9.95570e+00]
#  [2.00000e+00 8.61810e+00 6.09420e+00 1.39594e+01 1.16945e+01]
#  [3.00000e+00 9.00660e+00 6.06370e+00 1.30924e+01 1.13043e+01]
#  ...
#  [9.99800e+03 8.66250e+00 7.73060e+00 9.54690e+00 1.03063e+01]
#  [9.99900e+03 9.24560e+00 7.88860e+00 9.81510e+00 1.07564e+01]
#  [1.00000e+04 8.81350e+00 7.91700e+00 9.95170e+00 1.07848e+01]]

# %%
#we know have an array of data and we can obtain any element by slicing data[row,column]
data[5,2]
# Out:
# 6.2553

# %%
# We can also take 2D slices of an array to get a range of rows and a range of columns
small_data=data[0:10,0:3]
print(small_data)
# Out:
# [[ 1.      8.9542  5.8024]
#  [ 2.      8.6181  6.0942]
#  [ 3.      9.0066  6.0637]
#  [ 4.      9.2002  6.0227]
#  [ 5.      9.1294  5.9365]
#  [ 6.      9.0462  6.2553]
#  [ 7.      8.8657  5.9186]
#  [ 8.      9.3256  6.2351]
#  [ 9.      9.4184  6.1993]
#  [10.      9.06    6.0478]]

# %% [markdown]
# ### Analyzing Tabular Data

# %%
thr4_atp=data[:,1] #Every row, just the THR4_ATP column
avg_thr4_atp=numpy.mean(thr4_atp)
print(avg_thr4_atp)
# Out:
# 10.876950930000001

# %%
# If we want to alculate the average of each column we must use a for loop
num_columns=len(data[0,:])
for c in range(1,num_columns):
    avg=numpy.mean(data[:,c])
    method=headers[c]
    print(F'{method} : {avg}')
# Out:
# THR4_ATP : 10.876950930000001
# THR4_ASP : 7.342344959999999
# TYR6_ATP : 11.209791329999998
# TYR6_ASP : 10.9934435

# %% [markdown]
# ### Geometry Analysis Project
# In the lesson materials, there is a file in the data folder called “water.xyz”. This is a very simple, standard file format that is often used to distribute molecular coordinates. The first line of the file is the number of atoms in the molecule, the second line is a title line (or may be blank), and the coordinates begin on the third line. Write a code to read in the information from the xyz file and determine the bond lengths between all the atoms.

# %%
import numpy
import os

geofilename=os.path.join('data','water.xyz')

# %%
geodata=numpy.genfromtxt(fname=geofilename, dtype='unicode',skip_header=2)

# %%
print(geodata)
# Out:
# [['O' '0.000000' '-0.007156' '0.965491']
#  ['H1' '-0.000000' '0.001486' '-0.003471']
#  ['H2' '0.000000' '0.931026' '1.207929']]

# %%
geo_array=geodata[:,1:].astype(float)
atom = geodata[:,0]

print(atom)
print(geo_array)
# Out:
# ['O' 'H1' 'H2']
# [[ 0.       -0.007156  0.965491]
#  [-0.        0.001486 -0.003471]
#  [ 0.        0.931026  1.207929]]

# %%
num_atoms=len(atom)
for atom_1 in range(num_atoms):
    x_1=geo_array[atom_1,0]
    y_1=geo_array[atom_1,1]
    z_1=geo_array[atom_1,2]
    atomone=atom[atom_1]
    
    for atom_2 in range(num_atoms):
        x_2=geo_array[atom_2,0]
        y_2=geo_array[atom_2,1]
        z_2=geo_array[atom_2,2]
        atomtwo=atom[atom_2]
        
        dist=numpy.sqrt((x_1-x_2)**2+(y_1-y_2)**2+(z_1-z_2)**2)
        
        print(F'{atomone} to {atomtwo} : {dist}\n')
# Out:
# O to O : 0.0
#
# O to H1 : 0.9690005374652793
#
# O to H2 : 0.9690003348647513
#
# H1 to O : 0.9690005374652793
#
# H1 to H1 : 0.0
#
# H1 to H2 : 1.52693633514957
#
# H2 to O : 0.9690003348647513
#
# H2 to H1 : 1.52693633514957
#
# H2 to H2 : 0.0

# %% [markdown]
# #### Project Extension 1
# Your initial project calculated the distance between every set of atoms. However, some of these atoms aren’t really bonded to each other. H1 and H2 are not bonded for example, and all of the distances between an atom and itself are zero. Use a distance cutoff of 1.5 angstroms to define a bond (that is, if the bond length is greater than 1.5 angstroms, consider the atoms not bonded). Modify your code to only print the atoms that are actually bonded to each other.

# %%
num_atoms=len(atom)
for atom_1 in range(num_atoms):
    x_1=geo_array[atom_1,0]
    y_1=geo_array[atom_1,1]
    z_1=geo_array[atom_1,2]
    atomone=atom[atom_1]
    
    for atom_2 in range(num_atoms):
        x_2=geo_array[atom_2,0]
        y_2=geo_array[atom_2,1]
        z_2=geo_array[atom_2,2]
        atomtwo=atom[atom_2]
        
        dist=numpy.sqrt((x_1-x_2)**2+(y_1-y_2)**2+(z_1-z_2)**2)
        
        if dist<1.5 and dist>0:
            print(F'{atomone} to {atomtwo} : {dist}\n')
# Out:
# O to H1 : 0.9690005374652793
#
# O to H2 : 0.9690003348647513
#
# H1 to O : 0.9690005374652793
#
# H2 to O : 0.9690003348647513

# %% [markdown]
# ### Project Extension 2
# Some of these are actually the same bond length; for example, O to H1 and H1 to O refer to the same bond length. Remove the duplicates from your list.

# %%
listnum_atoms=len(atom)
distlist=[]
for atom_1 in range(num_atoms):
    x_1=geo_array[atom_1,0]
    y_1=geo_array[atom_1,1]
    z_1=geo_array[atom_1,2]
    atomone=atom[atom_1]
    
    for atom_2 in range(num_atoms):
        x_2=geo_array[atom_2,0]
        y_2=geo_array[atom_2,1]
        z_2=geo_array[atom_2,2]
        atomtwo=atom[atom_2]
        
        dist=numpy.sqrt((x_1-x_2)**2+(y_1-y_2)**2+(z_1-z_2)**2)
        
        if dist<1.5 and dist>0 and str(atomtwo)+' to '+ str(atomone)+' : ' +str(dist)+'\n' not in distlist:
            distlist.append(F'{atomone} to {atomtwo} : {dist}\n')            
for line in distlist:
    print(line)
# Out:
# O to H1 : 0.9690005374652793
#
# O to H2 : 0.9690003348647513

# %% [markdown]
# ### Project Extension 3
# Write a your output to a text file called bond_lengths.txt instead of just printing it to the screen.

# %%
outputfile=open('bond_lengths.txt','w+')
listnum_atoms=len(atom)
distlist=[]
for atom_1 in range(num_atoms):
    x_1=geo_array[atom_1,0]
    y_1=geo_array[atom_1,1]
    z_1=geo_array[atom_1,2]
    atomone=atom[atom_1]
    
    for atom_2 in range(num_atoms):
        x_2=geo_array[atom_2,0]
        y_2=geo_array[atom_2,1]
        z_2=geo_array[atom_2,2]
        atomtwo=atom[atom_2]
        
        dist=numpy.sqrt((x_1-x_2)**2+(y_1-y_2)**2+(z_1-z_2)**2)
        
        if dist<1.5 and dist>0 and str(atomtwo)+' to '+ str(atomone)+' : ' +str(dist)+'\n' not in distlist:
            distlist.append(F'{atomone} to {atomtwo} : {dist}\n')            
for line in distlist:
    outputfile.write(line)
    
outputfile.close()

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C02F-5876
#
#  Directory of C:\Users\samwi\OneDrive\Desktop\cms-workshop
#
# 11/28/2020  04:38 PM    <DIR>          .
# 11/28/2020  04:38 PM    <DIR>          ..
# 11/25/2020  10:34 AM    <DIR>          .ipynb_checkpoints
# 11/28/2020  04:27 PM            75,414 all_samples.png
# 11/29/2020  10:41 AM                60 bond_lengths.txt
# 11/21/2020  01:12 PM    <DIR>          data
# 11/21/2020  01:11 PM           237,019 data.zip
# 11/29/2020  10:41 AM               299 energies.txt
# 11/29/2020  10:41 AM             3,924 Etot.txt
# 11/28/2020  04:38 PM         1,056,376 MolSSI Workshop.ipynb
# 11/28/2020  04:27 PM            16,600 THR4_ASP.png
# 11/28/2020  04:27 PM            18,680 THR4_ATP.png
# 11/28/2020  04:27 PM            23,937 two_samples.png
# 11/28/2020  04:27 PM            16,806 TYR6_ASP.png
# 11/28/2020  04:27 PM            18,900 TYR6_ATP.png
#               11 File(s)      1,468,015 bytes
# ...

# %%
with open('bond_lengths.txt','r') as file:
    readingfile=file.readlines()

# %%
print(readingfile)
# Out:
# ['O to H1 : 0.9690005374652793\n', 'O to H2 : 0.9690003348647513\n']

# %%
for line in readingfile:
    print(line)
# Out:
# O to H1 : 0.9690005374652793
#
# O to H2 : 0.9690003348647513

# %% [markdown]
# ## Plotting and Data Vis

# %%
# We will use the data defined from the distance_data_headers.csv that we previously assigned to the variable data
# to be safe and make sure it is assigned to the proper variable, lets reimport it and assign to the variable data.

import os
import numpy

distance_file = os.path.join('data', 'distance_data_headers.csv')
distances = numpy.genfromtxt(fname=distance_file, delimiter=',', dtype='unicode')
headers = distances[0]
data = distances[1:]
data = data.astype(numpy.float)
print(data)
print(headers)
# Out:
# [[1.00000e+00 8.95420e+00 5.80240e+00 1.15478e+01 9.95570e+00]
#  [2.00000e+00 8.61810e+00 6.09420e+00 1.39594e+01 1.16945e+01]
#  [3.00000e+00 9.00660e+00 6.06370e+00 1.30924e+01 1.13043e+01]
#  ...
#  [9.99800e+03 8.66250e+00 7.73060e+00 9.54690e+00 1.03063e+01]
#  [9.99900e+03 9.24560e+00 7.88860e+00 9.81510e+00 1.07564e+01]
#  [1.00000e+04 8.81350e+00 7.91700e+00 9.95170e+00 1.07848e+01]]
# ['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']

# %% [markdown]
# ### Plotting Data

# %%
# To plot our data we will use the python library matplotlib

import matplotlib.pyplot

# %%
matplotlib.pyplot.figure() #This initializes a new figure
matplotlib.pyplot.plot(data[:,1])

# %%
"""matplotlib.pyplot is a lot to type every time we make a plot. Often, when people import python modules they give them a shorthand name so that they have to type less. For example, matplotlib.pyplot is commonly shortened to plt"""
import matplotlib.pyplot as plt

plt.figure()
plt.plot(data[:,1])

# %% [markdown]
# ### Labeling plots and saving figures

# %%
sample = headers [1] #this defines the sample the data is coming from, it is simply a variable assignment and has nothing to do with matplot

plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
fig_1=plt.plot(data[:,1],label=sample)
plt.legend()

plt.savefig(F'{sample}.png') # This will save the figure as THR4_ATP.png

# %% [markdown]
# ### Plotting more than one set of data
# To plot more than one data set on the same graph, we just add another plot command

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.plot(data[:,1], label=headers[1])
plt.plot(data[:,2], label=headers[2])
plt.legend()
plt.savefig('two_samples.png')

# %% [markdown]
# If we want to plot all samples on the same plot, we can use a for loop to loop through all the columns. We put the x and y labels and savefig command outside the loop since we only need to assign them once

# %%
"""I am confused with what all the functions here are doing and I would like
to know more?"""

for col in range(1,len(headers)):
    fig=plt.plot(data[:,col], label=headers[col])
    plt.legend()
    
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.savefig('all_samples.png')

# %%
# Exercise: How would you make a different plot for each sample? Save each image with the filename sample_name.png

for col in range(1,len(headers)):
    plt.figure()
    sample=headers[col]
    plt.plot(data[:,col], label=headers[col])
    plt.legend()
    plt.xlabel('Simulation Frame')
    plt.ylabel('Distance (angstrom)')
    plt.savefig(F'{sample}.png')

# %%
#Normalize axes using plt.ylim(low_limit,high_limit). We might want to know the min and max to choose these limits
data_min=numpy.min(data[:,1:])
data_max=numpy.min(data[:,1:])

# %%
# we might want a little breathing room so

data_min=numpy.min(data[:,1:])*0.9
data_max=numpy.max(data[:,1:])*1.1

# %%
# Now lets plot with these mins and max

for col in range(1, len(headers)):
    plt.figure()
    sample=headers[col]
    
    plt.plot(data[:,col],label=sample)
    plt.ylim(data_min, data_max)
    plt.legend()
    plt.xlabel('Simulation Frame')
    plt.ylabel('Distance (angstrom)')
    
    plt.savefig(F'{sample}.png')

# question can I save as a jpg or other format... future should look into matplot documentation

# %% [markdown]
# ### Plotting with x and y

# %%
"""Note: the plot function creates a line plot If there is only one argument
in the function, it will use that as as the y variable, with the x
variable just being a count. If we wanted to use the Frame column for our
x value, we would add it as the first argument of the plot"""

plt.figure()
plt.plot(data[:,0], data[:,1])

# %%
# To select frames at regular intervals, we can use the syntax array[start:stop:interval].
# to get every other row to the 10th row, we would use a start of 0, and end of 10, and an increment of 2. We then use the : to get every column.
print(data[0:10:2,:])
# if we wanted to go all the way to the end and start at the begining
print(data[::2,:])
# Out:
# [[ 1.      8.9542  5.8024 11.5478  9.9557]
#  [ 3.      9.0066  6.0637 13.0924 11.3043]
#  [ 5.      9.1294  5.9365 13.5321 10.6279]
#  [ 7.      8.8657  5.9186 12.9312 10.2176]
#  [ 9.      9.4184  6.1993 13.2614 10.366 ]]
# [[1.00000e+00 8.95420e+00 5.80240e+00 1.15478e+01 9.95570e+00]
#  [3.00000e+00 9.00660e+00 6.06370e+00 1.30924e+01 1.13043e+01]
#  [5.00000e+00 9.12940e+00 5.93650e+00 1.35321e+01 1.06279e+01]
#  ...
#  [9.99500e+03 8.60590e+00 7.44920e+00 8.78230e+00 1.07920e+01]
#  [9.99700e+03 8.95240e+00 7.46810e+00 9.51320e+00 1.09945e+01]
#  [9.99900e+03 9.24560e+00 7.88860e+00 9.81510e+00 1.07564e+01]]

# %%
#How would you get every 100th point in the first column?
print(data[::100,0])
# Out:
# [1.000e+00 1.010e+02 2.010e+02 3.010e+02 4.010e+02 5.010e+02 6.010e+02
#  7.010e+02 8.010e+02 9.010e+02 1.001e+03 1.101e+03 1.201e+03 1.301e+03
#  1.401e+03 1.501e+03 1.601e+03 1.701e+03 1.801e+03 1.901e+03 2.001e+03
#  2.101e+03 2.201e+03 2.301e+03 2.401e+03 2.501e+03 2.601e+03 2.701e+03
#  2.801e+03 2.901e+03 3.001e+03 3.101e+03 3.201e+03 3.301e+03 3.401e+03
#  3.501e+03 3.601e+03 3.701e+03 3.801e+03 3.901e+03 4.001e+03 4.101e+03
#  4.201e+03 4.301e+03 4.401e+03 4.501e+03 4.601e+03 4.701e+03 4.801e+03
#  4.901e+03 5.001e+03 5.101e+03 5.201e+03 5.301e+03 5.401e+03 5.501e+03
#  5.601e+03 5.701e+03 5.801e+03 5.901e+03 6.001e+03 6.101e+03 6.201e+03
#  6.301e+03 6.401e+03 6.501e+03 6.601e+03 6.701e+03 6.801e+03 6.901e+03
#  7.001e+03 7.101e+03 7.201e+03 7.301e+03 7.401e+03 7.501e+03 7.601e+03
#  7.701e+03 7.801e+03 7.901e+03 8.001e+03 8.101e+03 8.201e+03 8.301e+03
#  8.401e+03 8.501e+03 8.601e+03 8.701e+03 8.801e+03 8.901e+03 9.001e+03
# ...

# %%
# Make a plot with just every 100th point for the sample in column 2

plt.figure()
plt.plot(data[::100,0],data[::100,1],'--',label=headers[1])
plt.legend()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')

# We can change the marker or line type by adding another argument after our x and y values.
#For example, we can make our line dashed by adding '--'.
# Out:
# Text(0, 0.5, 'Distance (angstrom)')

# %%
#We can also change the line to markers
plt.figure()
plt.plot(data[::100,0],data[::100,1],'o',label=headers[1])
plt.legend()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
# Out:
# Text(0, 0.5, 'Distance (angstrom)')

# %%
#Or combine types and change colors
plt.figure()
plt.plot(data[::100,0],data[::100,1],':vk',label=headers[1])
plt.legend()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
# Out:
# Text(0, 0.5, 'Distance (angstrom)')

# %% [markdown]
# ### Multiple Plots with Subplot

# %%
#To create a figure which has several plots, you use the syntax 
#fig, ax = plt.subplots(nrows, ncolumns)

fig, ax=plt.subplots(len(headers)-1,1)

# %%
#We have two variables which resulted from this function fig and ax.
#Fig is our figure, while ax is a numpy array that represents our figure axes.
#The shape of this array will be dependent on the shape we specify that we
#want our subplots.

ax.shape
# Out:
# (4,)

# %%
fig2,ax2=plt.subplots(2,2)
ax2.shape
# Out:
# (2, 2)

# %%
# If we want to add data to our plots, we use the same slicing syntax we used 
# with numpy arrays.

ax[0].plot(data[::100,0],data[::100,1])

# %%
fig

# %%
ax2[0,0].plot(data[::100,0],data[::100,1])

# %%
fig2

# %%
fig,ax=plt.subplots(len(headers)-1,1)
for col in range(1,len(headers)):
    ax[col-1].plot(data[::100,0],data[::100,col],label=headers[col])
    ax[col-1].set_xlabel('Simulation Frame')
    ax[col-1].set_ylabel('Distance (angstrom)')
    ax[col-1].legend()

# %%
# Making subplots look better
#figsize will change the height and width in inches (here I make it 10 by 10)
# sharey or sharex will make all the y axes have the same limits.

fig,ax=plt.subplots(len(headers)-1,1,figsize=(10,10),sharey=True)

for col in range(1,len(headers)):
    ax[col-1].plot(data[::100,0],data[::100,col],label=headers[col])
    ax[col-1].set_xlabel('Simulation Frame')
    ax[col-1].set_ylabel('Distance (angstrom)')
    ax[col-1].legend()
plt.savefig('all_samples.png')

# %% [markdown]
# ## Writing Functions
# Functions are blocks of code which perform a particular task.
# We usually organize code into functions.
# Comercial software packages are composed of several functions.
# In general each function should perform only one computational task.

# %% [markdown]
# ### Defining and running a function
# Defined using def key word in the following form.

# %% [raw]
# def function_name(parameters):
#     **function body code**
#     return value_to_return

# %% [markdown]
# ### Writing functions into our geometery analysis project
# Lets go back and consider a possible solution for the geometry analysis project.

# %%
import numpy
import os

file_location = os.path.join('data', 'water.xyz')
xyz_file = numpy.genfromtxt(fname=file_location, skip_header=2, dtype='unicode')
symbols = xyz_file[:, 0]
coordinates = xyz_file[:, 1:]
coordinates = coordinates.astype(numpy.float)
num_atoms = len(symbols)
for num1 in range(0, num_atoms):
    for num2 in range(0, num_atoms):
        if num1 < num2:
            x_distance = coordinates[num1, 0] - coordinates[num2, 0]
            y_distance = coordinates[num1, 1] - coordinates[num2, 1]
            z_distance = coordinates[num1, 2] - coordinates[num2, 2]
            bond_length_12 = numpy.sqrt(x_distance ** 2 + y_distance ** 2 + z_distance ** 2)
            if bond_length_12 > 0 and bond_length_12 <= 1.5:
                print(F'{symbols[num1]} to {symbols[num2]} : {bond_length_12:.3f}')
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %%
# Let's change this code so that we write a func to cal the bond distance
def calculate_distance(atom1_coord,atom2_coord):
    x_distance=atom1_coord[0]-atom2_coord[0]
    y_distance=atom1_coord[1]-atom2_coord[1]
    z_distance=atom1_coord[2]-atom2_coord[2]
    bond_length_12=numpy.sqrt(x_distance**2+y_distance**2+z_distance**2)
    return bond_length_12

# %%
# Now we can shorten our for loop to just call the distanc func we wrote


file_location = os.path.join('data', 'water.xyz')
xyz_file = numpy.genfromtxt(fname=file_location, skip_header=2, dtype='unicode')
symbols = xyz_file[:, 0]
coordinates = xyz_file[:, 1:]
coordinates = coordinates.astype(numpy.float)
num_atoms = len(symbols)
for num1 in range(0, num_atoms):
    for num2 in range(0, num_atoms):
        if num1 < num2:
            bond_length_12=calculate_distance(coordinates[num1],coordinates[num2])
            if bond_length_12 > 0 and bond_length_12 <= 1.5:
                print(F'{symbols[num1]} to {symbols[num2]} : {bond_length_12:.3f}')
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %%
# Next let's write anothe funct that checks to see if a particular bond distance reperesents a bond.
def bond_check(atom_dist,min_dist=0,max_dist=1.5):
    if atom_dist>min_dist and atom_dist<=max_dist:
        return True
    else:
        return False

# %%
# Now lets modify our for loop to incorporate this function.

file_location = os.path.join('data', 'water.xyz')
xyz_file = numpy.genfromtxt(fname=file_location, skip_header=2, dtype='unicode')
symbols = xyz_file[:, 0]
coordinates = xyz_file[:, 1:]
coordinates = coordinates.astype(numpy.float)
num_atoms = len(symbols)
for num1 in range(0, num_atoms):
    for num2 in range(0, num_atoms):
        if num1 < num2:
            bond_length_12=calculate_distance(coordinates[num1],coordinates[num2])
            if bond_check(bond_length_12)==True:
                print(F'{symbols[num1]} to {symbols[num2]} : {bond_length_12:.3f}')
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %% [markdown]
# ### Function Documentation
# How can we make it so applying the help function to our function generates an informative string of text. For user defined funtions we must use docstrings to document our function. when you call help on something, it will display the docstring you have written.

# %%
def calculate_distance(atom1_coord,atom2_coord):
    """Calculate the distance between two three-dimensional points."""
    x_distance=atom1_coord[0]-atom2_coord[0]
    y_distance=atom1_coord[1]-atom2_coord[1]
    z_distance=atom1_coord[2]-atom2_coord[2]
    bond_length_12=numpy.sqrt(x_distance**2+y_distance**2+z_distance**2)
    return bond_length_12

# %%
help(calculate_distance)
# Out:
# Help on function calculate_distance in module __main__:
#
# calculate_distance(atom1_coord, atom2_coord)
#     Calculate the distance between two three-dimensional points.

# %%
def bond_check(atom_dist,min_dist=0,max_dist=1.5):
    """ Check if a distance is a bond based on a min and max bond length"""
    if atom_dist>min_dist and atom_dist<=max_dist:
        return True
    else:
        return False

# %%
help(bond_check)
# Out:
# Help on function bond_check in module __main__:
#
# bond_check(atom_dist, min_dist=0, max_dist=1.5)
#     Check if a distance is a bond based on a min and max bond length

# %% [markdown]
# ### Exercise
# write a function called open_xyz which takes an xyz file as a parameter and returns the symbols and coordinates.

# %%
def open_xyz(file_path):
    """Return the symbols,coordinates for each atom given the file path to a xyz file"""
    xyz_file = numpy.genfromtxt(fname=file_path, skip_header=2, dtype='unicode')
    symbols = xyz_file[:, 0]
    coordinates = xyz_file[:, 1:]
    coordinates = coordinates.astype(numpy.float)
    return symbols,coordinates

# %%
open_xyz(os.path.join('data','water.xyz'))
# Out:
# (array(['O', 'H1', 'H2'], dtype='<U9'),
#  array([[ 0.      , -0.007156,  0.965491],
#         [-0.      ,  0.001486, -0.003471],
#         [ 0.      ,  0.931026,  1.207929]]))

# %%
import os
import numpy

file_location = os.path.join('data', 'water.xyz')
symbols,coordinates=open_xyz(file_location)
num_atoms = len(symbols)
for num1 in range(0, num_atoms):
    for num2 in range(0, num_atoms):
        if num1 < num2:
            bond_length_12=calculate_distance(coordinates[num1],coordinates[num2])
            if bond_check(bond_length_12)==True:
                print(F'{symbols[num1]} to {symbols[num2]} : {bond_length_12:.3f}')
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %%
def print_bonds(atom_symbols, atom_coordinates):
    num_atoms = len(atom_symbols)
    for num1 in range(0,num_atoms):
        for num2 in range(0,num_atoms):
            if num1 < num2:
                bond_length_12=calculate_distance(coordinates[num1],coordinates[num2])
                if bond_check(bond_length_12)==True:
                    print(F'{symbols[num1]} to {symbols[num2]} : {bond_length_12:.3f}')

# %%
#Now we can make our cell even shorter

file_location = os.path.join('data', 'water.xyz')
symbols,coordinates=open_xyz(file_location)
num_atoms = len(symbols)
print_bonds(symbols,coordinates)
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %%
# For clarity I will rewrite all of our functions in one cell
import numpy
import os

def calculate_distance(atom1_coord, atom2_coord):
    """
    Calculate the distance between two three-dimensional points.
    """
    x_distance = atom1_coord[0] - atom2_coord[0]
    y_distance = atom1_coord[1] - atom2_coord[1]
    z_distance = atom1_coord[2] - atom2_coord[2]
    bond_length_12 = numpy.sqrt(x_distance ** 2 + y_distance ** 2 + z_distance ** 2)
    return bond_length_12

def bond_check(atom_distance, minimum_length=0, maximum_length=1.5):
    """Check if a distance is a bond based on a minimum and maximum bond length"""

    if atom_distance > minimum_length and atom_distance <= maximum_length:
        return True
    else:
        return False

def open_xyz(filename):
     """
     Open and read an xyz file. Returns tuple of symbols and coordinates.
     """
     xyz_file = numpy.genfromtxt(fname=filename, skip_header=2, dtype='unicode')
     symbols = xyz_file[:,0]
     coord = (xyz_file[:,1:])
     coord = coord.astype(numpy.float)
     return symbols, coord

def print_bonds(atom_symbols, atom_coordinates):
    """
    Prints atom symbols and bond length for a set of atoms.
    """
    num_atoms = len(atom_symbols)
    for num1 in range(0, num_atoms):
        for num2 in range(0, num_atoms):
            if num1 < num2:
                bond_length_12 = calculate_distance(atom_coordinates[num1], atom_coordinates[num2])
                if bond_check(bond_length_12) is True:
                    print(F'{atom_symbols[num1]} to {atom_symbols[num2]} : {bond_length_12:.3f}')

# %%
# We can now open any xyz file and print the bonded atoms
water_file_location=os.path.join('data','water.xyz')
water_symbols,water_coords=open_xyz(water_file_location)

benzene_file_location=os.path.join('data','benzene.xyz')
benzene_symbols,benzene_coords=open_xyz(benzene_file_location)

print(F'Printing bonds for water.')
print_bonds(water_symbols,water_coords)
print(F'Printing bonds for benzene.')
print_bonds(benzene_symbols,benzene_coords)
# Out:
# Printing bonds for water.
# O to H1 : 0.969
# O to H2 : 0.969
# Printing bonds for benzene.
# C to H : 1.088
# C to C : 1.403
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088

# %% [markdown]
# #### Extension
#  How could you use glob to print bonds for all the xyz files?

# %%
import glob
file_path=os.path.join('data','*.xyz')

# %%
file_path_list=glob.glob(file_path)

# %%
for file in file_path_list:
    molecule=os.path.basename(file)
    symbols,coords=open_xyz(file)
    print(F'Printing bonds for {molecule}.')
    print_bonds(symbols,coords)
# Out:
# Printing bonds for benzene.xyz.
# C to H : 1.088
# C to C : 1.403
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# Printing bonds for buckminsterfullerene.xyz.
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.395
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.395
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# ...

# %% [markdown]
# ## Running Code from the Linux Command Line
# How do I move code from the interactive jupyter notebook to run from the Linux command line?
# See the geom_analysis.py script
#
# ### The "main" part of our script
# When you write a code that includes function definitions and a main script, you need to tell python which part is the main script. After your import statements and function definitions and before use argparse.
# This is simply an if statement with the rest of the code idented.

# %% [markdown]
# Below you will find our completed code with required and optional user defined arguments that can be executed in the command line.

# %% [raw]
# import numpy
# import os
# import argparse
#
# def calculate_distance(atom1_coord, atom2_coord):
#     x_distance = atom1_coord[0] - atom2_coord[0]
#     y_distance = atom1_coord[1] - atom2_coord[1]
#     z_distance = atom1_coord[2] - atom2_coord[2]
#     bond_length_12 = numpy.sqrt(x_distance**2+y_distance**2+z_distance**2)
#     return bond_length_12
#
# def bond_check(atom_distance, minimum_length=0, maximum_length=1.5):
#     if atom_distance > minimum_length and atom_distance <= maximum_length:
#         return True
#     else:
#         return False
#
# def open_xyz(filename):
#      xyz_file = numpy.genfromtxt(fname=filename, skip_header=2, dtype='unicode')
#      symbols = xyz_file[:,0]
#      coord = (xyz_file[:,1:])
#      coord = coord.astype(numpy.float)
#      return symbols, coord
#
# if __name__=="__main__":
#
#     parser=argparse.ArgumentParser(description='This script analyzes a user given xyz file and outputs the length of the bonds.')
#     parser.add_argument('xyz_file',help='The filepath for the xyz file to analyze')
#     args=parser.parse_args()
#     xyzfilename=args.xyz_file
#
#     parser.add_argument('-minimum_length', help='The minimum distance to consider atoms bonded.', type=float, default=0)
#     parser.add_argument('-maximum_length', help='The maximum distance to consider atoms bonded.', type=float, default=1.5)'
#     symbols, coord = open_xyz(xyzfilename)
#     num_atoms = len(symbols)
#     for num1 in range(0,num_atoms):
#          for num2 in range(0,num_atoms):
#              if num1<num2:
#                  bond_length_12 = calculate_distance(coord[num1], coord[num2])
#                  if bond_check(bond_length_12,minimum_length=args.minimum_length,maximum_length=args.maximum_length) is True:
#                      print(F'{symbols[num1]} to {symbols[num2]} : {bond_length_12:.3f}')

# %% [markdown]
# ### Project Assignment
# you will return to your first project where you processed the file 03_Prod.mdout.
#
# Create a command line script using argparse which can take in an mdout file from Amber, pull out total energy for each time step, and write a new file containing these values. The script should take a file name (03_Prod.mdout) and output a file with the names filename_Etot.txt. Modify your week 1 homework to do this.
#
# In the first project, the file we wrote had two values at the end which we did not want for the total energy. The last two values were some statistics associated with the md simulation and were not total energies.
#
# Call your script analyze_mdout.py

# %% [markdown]
# ## Testing Code with pytest
# Unit Testing: Testing each part of your code individually
#
# Integration Testing: Testing how the parts of your code work together
#
# ### Writing Unit Tests
#
# The pytest package automatically looks for tests in files whose name start with the word test. If you have a function beginning with the word test in a module beginning with the word test, pytest will run the code in that function. If the function does not result in an error, the test passes.
#
# We write a new code (saved as test_*.py in the same directory as our test file). In this new code we import the the code containing the functions to be tested, then write functions that test these functions.
#
# example of test function below

# %% [raw]
# def test_calculate_distance():
#     coord1 = [0, 0, 0]
#     coord2 = [1, 0, 0]
#     expected = 1.0
#     observed = ga.calculate_distance(coord1,coord2)
#     assert observed == expected

# %% [markdown]
# You should always make sure to test edge cases in your functions.

# %% [markdown]
# ### Raising Errors
# We can raise errors by using the syntax

# %% [raw]
# raise ErrorType('Your error message here')

# %% [markdown]
# in your function with an if statement.
#
# You can also write test functions to ensure the error is raised

# %% [raw]
# import pytest
#
# def test_bond_check_negative():
#     distance = -1
#     expected = False
#     with pytest.raises(ValueError)
#         calculated = ga.bond_check(distance)

# %% [markdown]
# ## Version Control with git
# Version control keeps a complete history of your work on a given project. It facilitates collaboration on projects where everyone can work freely on a part of the project without overriding others’ changes. You can move between past versions and rollback when needed. Also, you can review the history of your project through commit messages that describe changes on the source code and see what exactly has been modified in any given commit. You can see who made the changes and when it happened.
#
# ### git and GitHub
